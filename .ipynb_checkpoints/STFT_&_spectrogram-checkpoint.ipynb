# %%
import os
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt

# %%
scale_file = "./audio/scale.wav"
debussy_file = "./audio/debussy.wav"
redhot_file = './audio/redhot.wav'
duke_file = "./audio/duke.wav"

# %%
scale, sr = librosa.load(scale_file)
debussy, _ = librosa.load(debussy_file)
redhot , _ = librosa.load(redhot_file)
duke, _ = librosa.load(duke_file)

# %% [markdown]
# ### STFT

# %%
frame_size = 2048
hop_size = 512

# %%
S_scale = librosa.stft(scale, n_fft=frame_size, hop_length=hop_size)

# %%
S_scale.shape
# Out:
# (1025, 342)

# %%
type(S_scale[0][0])
# Out:
# numpy.complex64

# %% [markdown]
# ### Calculating Spectrogram/

# %%
Y_scale = np.abs(S_scale**2)

# %%
type(Y_scale[0][0])
# Out:
# numpy.float32

# %%
def plot_spectrogram(Y, sr, hop_length, y_axis = 'linear'):
    plt.figure(figsize=(25,10))
    librosa.display.specshow(Y,
                            sr=sr,
                            hop_length=hop_length,
                            x_axis = 'time',
                            y_axis = y_axis 
                            )
    plt.colorbar()

# %%
plot_spectrogram(Y_scale, sr, hop_size)
#linear representation

# %% [markdown]
# ## Log-Amplitude

# %%
Y_log_scale = librosa.power_to_db(Y_scale)
plot_spectrogram(Y_log_scale,sr,hop_size)

# %% [markdown]
# ## Log-frequency

# %%
plot_spectrogram(Y_log_scale,sr, hop_size, y_axis='log')

# %%
S_debussy = librosa.stft(debussy, n_fft=frame_size, hop_length=hop_size)
S_duke = librosa.stft(duke, n_fft=frame_size, hop_length=hop_size)
S_redhot = librosa.stft(redhot, n_fft=frame_size, hop_length=hop_size)

Y_debussy_log = librosa.power_to_db(np.abs(S_debussy**2))
Y_duke_log = librosa.power_to_db(np.abs(S_duke**2))
Y_redhot_log = librosa.power_to_db(np.abs(S_redhot**2))

plot_spectrogram(Y_debussy_log,sr, hop_size, y_axis='log')
plot_spectrogram(Y_duke_log ,sr, hop_size, y_axis='log')
plot_spectrogram(Y_redhot_log,sr, hop_size, y_axis='log')
